# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
img = cv2.imread("/content/drive/MyDrive/Colab/Buah Mengkal/Mengkal PKS 26 (11).jpg")

# %%
def show_image(img, title='Image', cmap_type='gray'):
    plt.imshow(img, cmap=cmap_type)
    plt.title(title)
    plt.axis('off')

# %%
print(f'image shape:{img.shape}')
# Out:
# image shape:(1599, 899, 3)

# %%
from skimage import data, color

# Convert the image to grayscale
gray_scaled_img = color.rgb2gray(img)

# Show the original image
show_image(img, 'Original RGB image');

# %%
# Show the grayscale image
show_image(gray_scaled_img, 'Grayscale image')

# %%
# Flip the image vertically
img_vertical_flip = np.flipud(img)

# Show the resulting image
show_image(img_vertical_flip, 'vertically plipped')

# %%
# Flip the previous image horizontally
img_horizontal_flip = np.fliplr(img_vertical_flip)
# Show the resulting image
show_image(img_horizontal_flip, 'horizontally flipped')

# %%
image = plt.imread('/content/drive/MyDrive/Colab/Buah Mengkal/Mengkal PKS 26 (11).jpg')

# Obtain the red channel
red_channel = image[:, :, 0]

# Plot the the red histogram with bins in a range of 256
plt.hist(red_channel.ravel(), bins=256, color='red');

# Set title
plt.title('Red Histogram');

# %%
from skimage.filters import threshold_otsu

chess_pieces_image = plt.imread('/content/drive/MyDrive/Colab/Buah Mengkal/Mengkal PKS 26 (11).jpg')

# Make the image grayscale using rgb2gray
chess_pieces_image_gray = color.rgb2gray(chess_pieces_image)

# Obtain the optimal threshold value with otsu
thresh = threshold_otsu(chess_pieces_image_gray)

# Apply thresholding to the image #true atau false
binary = chess_pieces_image_gray > thresh

# Show the image
show_image(binary, 'Binary image')

# %%
from skimage.filters import try_all_threshold

fruits_image = plt.imread('/content/drive/MyDrive/Colab/Buah Mengkal/Mengkal PKS 26 (11).jpg')

# Turn the fruits_image to grayscale
grayscale = color.rgb2gray(fruits_image)

# Use the try all method on the resulting grayscale image
fig, ax = try_all_threshold(grayscale, verbose=False);

# %%
tools_image = plt.imread('/content/drive/MyDrive/Colab/Buah Mengkal/Mengkal PKS 26 (11).jpg')

# Turn the image grayscale
gray_tools_image = color.rgb2gray(tools_image)

# Obtain the optimal thresh
thresh = threshold_otsu(gray_tools_image)

# Obtain the binary image by applying thresholding
binary_image = gray_tools_image > thresh

# Show the resulting binary image
show_image(binary_image, 'Binarized image')

# %%
#importing required libraries
import cv2
import numpy as np
from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.feature import hog
from skimage import exposure
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#reading the image
img = cv2.imread("/content/drive/MyDrive/Colab/Buah Mengkal/Mengkal PKS 26 (10).jpg")
imshow(img)
print(img.shape)
# Out:
# (2080, 1560, 3)

# %%
#resizing image
resized_img = resize(img, (128,64))
imshow(resized_img)
print(resized_img.shape)
# Out:
# (128, 64, 3)

# %%
from skimage.feature import hog

fd, hog_image = hog(resized_img, orientations=9, pixels_per_cell=(8, 8),
                    cells_per_block=(2, 2), visualize=True, channel_axis=-1)

# %%
fd.shape
# Out:
# (3780,)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 8), sharex=True, sharey=True)

ax1.imshow(resized_img, cmap=plt.cm.gray)
ax1.set_title('Input image')

# Rescale histogram for better display
hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 10))

ax2.imshow(hog_image_rescaled, cmap=plt.cm.gray)
ax2.set_title('Histogram of Oriented Gradients')

plt.show()

# %%
from skimage import data, color

# Convert the image to grayscale
gray_scaled_img = color.rgb2gray(img)

# Show the original image
show_image(gray_scaled_img, 'Grayscale image');

# %%
#resizing image
resized_img_gray = resize(gray_scaled_img, (128,64))
imshow(resized_img_gray)
print(resized_img_gray.shape)
# Out:
# (128, 64)

# %%
from skimage.feature import hog

fd, hog_image = hog(resized_img_gray, orientations=9, pixels_per_cell=(8, 8),
                    cells_per_block=(2, 2), visualize=True)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 8), sharex=True, sharey=True)

ax1.imshow(resized_img_gray, cmap=plt.cm.gray)
ax1.set_title('Input image')

# Rescale histogram for better display
hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 10))

ax2.imshow(hog_image_rescaled, cmap=plt.cm.gray)
ax2.set_title('Histogram of Oriented Gradients')

plt.show()
